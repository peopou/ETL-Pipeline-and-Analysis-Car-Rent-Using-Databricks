# %%
import pandas as pd

df = pd.read_csv('vehicle_rental_2024_100cars.csv')
df.columns
# Out:
# Index(['transaction_id', 'rental_date', 'customer_name', 'customer_phone',
#        'customer_email', 'customer_city', 'customer_age', 'customer_gender',
#        'vehicle_id', 'vehicle_plate', 'vehicle_brand', 'vehicle_model',
#        'vehicle_year', 'vehicle_type', 'vehicle_fuel', 'pickup_location',
#        'return_location', 'pickup_location_city', 'return_location_city',
#        'rental_duration_days', 'daily_rate', 'discount_percent',
#        'total_amount', 'payment_method', 'payment_status', 'include_driver',
#        'driver_name', 'expected_return_date', 'actual_return_date',
#        'is_late_return', 'penalty_fee'],
#       dtype='object')
